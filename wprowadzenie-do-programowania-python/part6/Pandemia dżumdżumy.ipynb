# %% [markdown]
# # Pandemia dżumdżumy
#
# Rozważmy sobie hipotetyczną kolejną straszną chorobę, która nawiedza nasze społeczeństwo. Czy z wykorzystaniem Pythona możemy sobie zamodelować jej rozprzestrzenianie.

# %% [markdown]
# Zadania o charakterze symulacji są jednymi z najlepszych technik prezentowania aspektów programowania obiektowego. Podobnie jak ... gry komputerowe. Dzięki zbliżeniu kodu do metaforycznych tworów - można dostrzec istotny potencjał w tym sposobie organizacji kodu. Poza tym pozwala on również na wcielenie się w rolę lokalnego boga i definiowanie wszystkich praw i możliwości jakie obowiązują w danym miejscu.

# %% [markdown]
# _Z kraju ukrytego w wysokich himalajach Dżumurii, jeden z mieszkańców dostał się do starożytnej jaskini, zamarzniętej pod lodowcem setki tysięcy lat temu i zakaził się antycznym - rozmrożonym wirusem. Podrużując do Indii po pomoc medyczną rozpoczął nową światową pandemię choroby znanej jak Dżumdżuma._

# %% [markdown]
# ![image](https://i.ytimg.com/vi/-1qju6V1jLM/maxresdefault.jpg)

# %% [markdown]
# Poznajmy naszych aktorów.
#
# Pierwszym jest oczywiście nasz staruszek świat który musimy zostać jakoś ujęty

# %%
from random import random, sample, randrange

class Swiat(object):
    
    def __init__(self, liczba_ludzi = 0, liczba_chorych = 0, liczba_spotkan = 2):
        self.rok = 2020
        self.dzien = 0
        self.liczba_spotkan = liczba_spotkan
        self.populacji = []
        for _ in range(liczba_chorych):
            nowy_czlowiek = Czlowiek()
            nowa_choroba = Choroba() #tworzymy chorobe
            nowy_czlowiek.choroba = nowa_choroba #przypisujemy chorobe do czlowieka
            self.populacji.append(nowy_czlowiek) #dolacz go do populacji swiata
        for _ in range(liczba_ludzi - liczba_chorych):
            nowy_czlowiek = Czlowiek() #stworz nowego czlowieka
            self.populacji.append(nowy_czlowiek) #dolacz go do populacji swiata
    
    def mija_dzien(self):
        self.dzien += 1
        if self.dzien % 365 == 0:
            self.rok += 1
            self.dzien = 0
        
        for czlowiek in self.populacji:
            #losujemy ludzi z ktorymi sie on tego dnia spotka
            for spotkanego_czlowieka in sample(self.populacji, self.liczba_spotkan):
                czlowiek.kontakt(spotkanego_czlowieka)
                spotkanego_czlowieka.kontakt(czlowiek)
        
        print(f'\nMamy dzien {self.dzien:3} roku {self.rok}', end=' ')
        choroby = []
        
        zywi = []
        for czlowiek in self.populacji:
            if czlowiek.czy_zywy():
                zywi.append(czlowiek)
        self.populacji = zywi         
        
        for czlowiek in self.populacji:
            czlowiek.mija_dzien()
            if czlowiek.choroba is not None:
                choroby.append(czlowiek.choroba)
        for choroba in choroby:
            choroba.mija_dzien()
        self.wypisz_stan_pandemii()
            
    
    def wypisz_stan_pandemii(self):
        liczba_ludzi = len(self.populacji)
        chory = []
        for czlowiek in self.populacji:
            if czlowiek.czy_chory():
                chory.append(czlowiek)
        liczba_chorych = len(chory)
        
        print(f'Populacja liczy {liczba_ludzi:5} osób z których chorych jest {liczba_chorych:5}', end = ' ')
        print(f'Stanowi to {int(liczba_chorych/liczba_ludzi * 100):3}% całej populacji', end =' ')
        
    def uruchom_przez(self, dni):
        for _ in range(dni):
            self.mija_dzien()

# %% [markdown]
# Kolejnym jest nasz człowieczek (a w zasadzie ich mnogość)

# %%
class Czlowiek(object):
    
    def __init__(self):
        self.zdrowie = 100
        self.odpornosc = 0
        self.choroba = None
    
    def mija_dzien(self):
        
        if self.choroba is not None and self.choroba.czy_koniec(): # chorowal, ale choroba juz mija
            self.choroba = None #wyzdrowial
            self.odpornosc = 100
            
        if self.choroba is None and self.zdrowie < 100:
            self.zdrowie += 2
        elif self.choroba is not None:
            self.zdrowie -= self.choroba.szkodliwosc
        
        if self.odpornosc > 0:
            self.odpornosc -= 1

    def czy_chory(self):
        return self.choroba is not None
    
    def czy_zywy(self):
        return self.zdrowie > 0
    
    def kontakt(self, inny_czlowiek):
        if self.choroba is not None and inny_czlowiek.choroba is None:
            losowa = random() #(0,1)
            if int(losowa * 100) > inny_czlowiek.odpornosc:
                nowa_choroba = Choroba() # tworzona jest kolejna choroba
                inny_czlowiek.choroba = nowa_choroba

# %% [markdown]
# Ostatnim (przynajmniej na początku) aktorem jest oczywiście choroba, która za pomocą ludzi się roznosi

# %%
class Choroba(object):
    
    def __init__(self):
        self.trwania = 0
        self.szkodliwosc = randrange(5,12) # wylosowac z przedzialu [5,12]
    
    def mija_dzien(self):
        self.trwania += 1
        
    def czy_koniec(self):
        czas_trwania = 15
        return self.trwania > czas_trwania

# %% [markdown]
# Poza tym potrzebny nam setup (konfiguracja początkowa) oraz start całej symulacji

# %%
swiat = Swiat(liczba_ludzi = 10000, liczba_chorych = 1, liczba_spotkan = 5)
swiat.uruchom_przez(180)
# Out:
# Mamy dzien   1 roku 2020 Populacja liczy 10000 osób z których chorych jest  9805 Stanowi to  98% całej populacji
# Mamy dzien   2 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien   3 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien   4 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien   5 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien   6 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien   7 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien   8 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien   9 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien  10 roku 2020 Populacja liczy 10000 osób z których chorych jest 10000 Stanowi to 100% całej populacji
# Mamy dzien  11 roku 2020 Populacja liczy  7186 osób z których chorych jest  7186 Stanowi to 100% całej populacji
# Mamy dzien  12 roku 2020 Populacja liczy  7121 osób z których chorych jest  7121 Stanowi to 100% całej populacji
# Mamy dzien  13 roku 2020 Populacja liczy  5687 osób z których chorych jest  5687 Stanowi to 100% całej populacji
# Mamy dzien  14 roku 2020 Populacja liczy  4319 osób z których chorych jest  4319 Stanowi to 100% całej populacji
# Mamy dzien  15 roku 2020 Populacja liczy  4291 osób z których chorych jest  4291 Stanowi to 100% całej populacji
# Mamy dzien  16 roku 2020 Populacja liczy  2810 osób z których chorych jest  2810 Stanowi to 100% całej populacji
# Mamy dzien  17 roku 2020 Populacja liczy  2783 osób z których chorych jest    47 Stanowi to   1% całej populacji
# Mamy dzien  18 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  19 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  20 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  21 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  22 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  23 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  24 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  25 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  26 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  27 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  28 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  29 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  30 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  31 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  32 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  33 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  34 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  35 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  36 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  37 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  38 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  39 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  40 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  41 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  42 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  43 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  44 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  45 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  46 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  47 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  48 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  49 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  50 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  51 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  52 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  53 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  54 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  55 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  56 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  57 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  58 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  59 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  60 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  61 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  62 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  63 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  64 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  65 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  66 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  67 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  68 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  69 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  70 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  71 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  72 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  73 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  74 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  75 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  76 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  77 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  78 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  79 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  80 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  81 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  82 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  83 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  84 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  85 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  86 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  87 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  88 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  89 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  90 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  91 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  92 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  93 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  94 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  95 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  96 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  97 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  98 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien  99 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 100 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 101 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 102 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 103 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 104 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 105 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 106 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 107 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 108 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 109 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 110 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 111 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 112 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 113 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 114 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 115 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 116 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 117 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 118 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 119 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 120 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 121 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 122 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 123 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 124 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 125 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 126 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 127 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 128 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 129 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 130 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 131 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 132 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 133 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 134 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 135 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 136 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 137 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 138 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 139 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 140 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 141 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 142 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 143 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 144 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 145 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 146 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 147 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 148 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 149 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 150 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 151 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 152 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 153 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 154 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 155 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 156 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 157 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 158 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 159 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 160 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 161 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 162 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 163 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 164 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 165 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 166 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 167 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 168 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 169 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 170 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 171 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 172 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 173 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 174 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 175 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 176 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 177 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 178 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 179 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji
# Mamy dzien 180 roku 2020 Populacja liczy  2783 osób z których chorych jest     0 Stanowi to   0% całej populacji

# %% [markdown]
# # Jak rozwinąć model dżumdżumy
#
# Przygotowany tu kod można łatwo rozszerzyć - dodając mu pewne wymagania
#
# W szczególności możemy np.
#
# * Dopisać jak wyglądają wzorce zależności - czyli np. pogrupować ludzi względem rodzin, współpracowników;
# * Możemy rozszerzyć klasę Człowieka i stworzyć klasę pochodną Lekarz i nadać jej zadania oraz wpływ na kształt rozwoju choroby;
# * Wprowadzić szczepienia;
# * Wprowadzić kwarantanny, obostrzenia i co nam się spodoba;
# * Wprowadzić stadia choroby: inkubacja i postać pełnoobjawowa;
# * Wprowadzić różny przebieg w zależności od wieku;
# * ...
# * Można dodać do człowieka pole płeć i nadać dżumdżumie własności zupełnie innej rodziny chorób;

# %% [markdown]
# # Co na teraz
#
# Pobrać sobie plik `pandemia_dzumdzumy.py` z repozytorium `https://github.com/centrum-mistrzostwa-informatycznego/cmi-edition3`
#
# * (Dla bardzo początkujących) pytać - ja odpowiadam i wyjaśniam.
# * (Dla przeciętnych) uruchomić sobie samodzielnie tę symulację. Może zmodyfikować pewne parametry symulacji. Jak ilość kontaktów, czas trwania choroby. Zmienić parametry życiowe ludzi lub chorób.
# * Spróbować wprowadzić jakaś niewielką zmianę w sposobie działania tego świata i zobaczyć jej wpływ na stan świata.
